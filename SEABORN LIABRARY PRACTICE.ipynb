# %%
import seaborn as sns

# %%
df= sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## HeatMap

# %%
df.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(df.corr())

# %% [markdown]
# ## Bivariant Analysis or Join Plot

# %%
sns.jointplot(x='tip',y='total_bill',data=df,kind='hex')

# %% [markdown]
# Max value lies between 20 dollar and 10 dollar bill

# %%
sns.jointplot(x='tip',y='total_bill',data=df,kind='reg')

# %% [markdown]
# ## Pair Plot

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue='sex')

# %%
sns.pairplot(df,hue='smoker')

# %%
sns.distplot(df['tip'],kde=False,bins=10)

# %% [markdown]
# ## For categorical features

# %% [markdown]
# ### Box Plot

# %%
sns.boxplot(x='sex',y='tip',data=df)

# %%
sns.barplot(x='smoker',y='total_bill',data=df)

# %%
sns.countplot('sex',data=df)

# %%
sns.countplot(y='smoker',data=df)

# %%
sns.boxplot(data=df, orient='v')

# %%
sns.violinplot(x='total_bill',y='smoker',data=df)

# %%
df= sns.load_dataset('iris')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(df.corr())

# %% [markdown]
# Conclusion:
# - Sepal Length and Petal Width are highly possitivly correlated
# - Sepal Length and Sepal Width are neagtivly correlated
# - Petal Lenght and Petal Width are highly possitivly correlated

# %%
sns.jointplot(x='sepal_length',y='petal_width',data=df)

# %%
sns.pairplot(df,hue='species')

# %%
sns.boxplot(data=df)

# %%
sns.countplot(x='sepal_length',data=df)

# %%
sns.barplot(x='sepal_length',y='petal_length',data=df,hue='species')

# %%
sns.jointplot(x='sepal_length',y='petal_length',data=df,kind='hex')

# %%
sns.jointplot(x='sepal_length',y='petal_length',data=df,kind='reg')
